# %%
from decoder import TranslatorBase

# %% [markdown]
# Now we want to enter some kind of string to be translated

# %%
input_string='... --- ...'
delimiter=' '

# %% [markdown]
# Now we can initialise our class

# %%
translator=TranslatorBase(input_string, delimiter)

# %% [markdown]
# Finally watch it go!

# %%
translator()
# Out:
# It's in morse!
# Translates to SOS
#
# Can't convert input to grid
# Examining ['S', 'O', 'S']
#
#  Character frequency is : {'O': 1, 'S': 2}
#
# Letter->Base 10 numerical value is : ['18', '14', '18']
# Alphabet->Keyboard pos : LIL
# Keyboard pos->Alphabet : LGL
# This is '['\x01\x08', '\x01\x04', '\x01\x08']' in ascii
# Detected numerical result, converting from base 9->10 to 10 and looking at ascii, binary etc.
#
# ------------------------------------------------------
# Now using base 9
# ['18', '14', '18'] in base 9 is [17, 13, 17]  in base 10
# Alphabetic (num->letter) is ['Q', 'M', 'Q']
# If we go from keyboard->alphabet we get JDJ
# If we go from alphabet->keyboard we get AZA
# ------------------------------------------------------
#
# ------------------------------------------------------
# Now using base 10
# ['18', '14', '18'] in base 10 is [18, 14, 18]  in base 10
# Alphabetic (num->letter) is ['R', 'N', 'R']
# If we go from keyboard->alphabet we get KFK
# ...
